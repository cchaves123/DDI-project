# %%
import torch
data = torch.load('/Users/cdonnat/Downloads/data_{1}.pt')

# %%
data
# Out:
# HeteroData(
#   drug={ x=         amino acids, peptides, and proteins  anticoagulants  \
# DB00001                                  1.0             1.0
# DB00002                                  1.0             0.0
# DB00003                                  1.0             0.0
# DB00004                                  1.0             0.0
# DB00005                                  1.0             0.0
# ...                                      ...             ...
# DB16419                                  0.0             0.0
# DB16420                                  0.0             0.0
# DB16421                                  1.0             0.0
# DB16422                                  0.0             0.0
# DB16423                                  0.0             0.0
#
#          antithrombin proteins  antithrombins  \
# DB00001                    1.0            1.0
# DB00002                    0.0            0.0
# DB00003                    0.0            0.0
# ...
